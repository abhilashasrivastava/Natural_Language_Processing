# %%
# !pip install opendatasets

# %%
import opendatasets as od

# %%
od.download('https://www.kaggle.com/datasets/saurabhshahane/ecommerce-text-classification')
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: abhilasha2003
# Your Kaggle Key: ··········
# ...
# 100%|██████████| 7.86M/7.86M [00:01<00:00, 7.72MB/s]

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/ecommerce-text-classification/ecommerceDataset.csv',names = ["category","description"],header = None)
df.shape
# Out:
# (50425, 2)

# %%
df.head()
# Out:
#     category                                        description
# 0  Household  Paper Plane Design Framed Wall Hanging Motivat...
# 1  Household  SAF 'Floral' Framed Painting (Wood, 30 inch x ...
# 2  Household  SAF 'UV Textured Modern Art Print Framed' Pain...
# 3  Household  SAF Flower Print Framed Painting (Synthetic, 1...
# 4  Household  Incredible Gifts India Wooden Happy Birthday U...

# %%
df.category.value_counts()
# Out:
# category
# Household                 19313
# Books                     11820
# Electronics               10621
# Clothing & Accessories     8671
# Name: count, dtype: int64

# %%
df.dropna(inplace = True)

# %%
df.shape
# Out:
# (50424, 2)

# %%
df.category.replace('Clothing & Accessories',"Clothing_Accessories", inplace = True)

# %%
df.category.unique()
# Out:
# array(['Household', 'Books', 'Clothing_Accessories', 'Electronics'],
#       dtype=object)

# %%
df['category'] = '__label__' + df['category'].astype(str)
df.head(5)
# Out:
#              category                                        description
# 0  __label__Household  Paper Plane Design Framed Wall Hanging Motivat...
# 1  __label__Household  SAF 'Floral' Framed Painting (Wood, 30 inch x ...
# 2  __label__Household  SAF 'UV Textured Modern Art Print Framed' Pain...
# 3  __label__Household  SAF Flower Print Framed Painting (Synthetic, 1...
# 4  __label__Household  Incredible Gifts India Wooden Happy Birthday U...

# %%
df.head()
# Out:
#              category                                        description
# 0  __label__Household  Paper Plane Design Framed Wall Hanging Motivat...
# 1  __label__Household  SAF 'Floral' Framed Painting (Wood, 30 inch x ...
# 2  __label__Household  SAF 'UV Textured Modern Art Print Framed' Pain...
# 3  __label__Household  SAF Flower Print Framed Painting (Synthetic, 1...
# 4  __label__Household  Incredible Gifts India Wooden Happy Birthday U...

# %%
df['category_description'] = df['category'] + " " +df['description']

# %%
df.head()
# Out:
#              category                                        description  \
# 0  __label__Household  Paper Plane Design Framed Wall Hanging Motivat...
# 1  __label__Household  SAF 'Floral' Framed Painting (Wood, 30 inch x ...
# 2  __label__Household  SAF 'UV Textured Modern Art Print Framed' Pain...
# 3  __label__Household  SAF Flower Print Framed Painting (Synthetic, 1...
# 4  __label__Household  Incredible Gifts India Wooden Happy Birthday U...
#
#                                 category_description
# 0  __label__Household Paper Plane Design Framed W...
# 1  __label__Household SAF 'Floral' Framed Paintin...
# 2  __label__Household SAF 'UV Textured Modern Art...
# 3  __label__Household SAF Flower Print Framed Pai...
# 4  __label__Household Incredible Gifts India Wood...

# %%
df['category_description'][0]
# Out:
# '__label__Household Paper Plane Design Framed Wall Hanging Motivational Office Decor Art Prints (8.7 X 8.7 inch) - Set of 4 Painting made up in synthetic frame with uv textured print which gives multi effects and attracts towards it. This is an special series of paintings which makes your wall very beautiful and gives a royal touch. This painting is ready to hang, you would be proud to possess this unique painting that is a niche apart. We use only the most modern and efficient printing technology on our prints, with only the and inks and precision epson, roland and hp printers. This innovative hd printing technique results in durable and spectacular looking prints of the highest that last a lifetime. We print solely with top-notch 100% inks, to achieve brilliant and true colours. Due to their high level of uv resistance, our prints retain their beautiful colours for many years. Add colour and style to your living space with this digitally printed painting. Some are for pleasure and 
# ...

# %%
#preprocessing

# %%
import re
text = '__label__HouseholdPaper Plane Design Framed Wall Hanging Motivational Office Decor Art Prints (8.7 X 8.7 inch) - Set of 4 Painting made up in synthetic frame with uv textured print which gives multi effects and attracts towards it. This is an special series of paintings which makes your wall very beautiful and gives a royal touch. This painting is ready to hang, you would be proud to possess this unique painting that is a niche apart. We use only the most modern and efficient printing technology on our prints, with only the and inks and precision epson, roland and hp printers. This innovative hd printing technique results in durable and spectacular looking prints of the highest that last a lifetime. We print solely with top-notch 100% inks, to achieve brilliant and true colours. Due to their high level of uv resistance, our prints retain their beautiful colours for many years. Add colour and style to your living space with this digitally printed painting. Some are for pleasure and some'
text = re.sub(r'[^\w\s\']',' ', text)
text = re.sub(' +', ' ', text)
text.strip().lower()
# Out:
# '__label__householdpaper plane design framed wall hanging motivational office decor art prints 8 7 x 8 7 inch set of 4 painting made up in synthetic frame with uv textured print which gives multi effects and attracts towards it this is an special series of paintings which makes your wall very beautiful and gives a royal touch this painting is ready to hang you would be proud to possess this unique painting that is a niche apart we use only the most modern and efficient printing technology on our prints with only the and inks and precision epson roland and hp printers this innovative hd printing technique results in durable and spectacular looking prints of the highest that last a lifetime we print solely with top notch 100 inks to achieve brilliant and true colours due to their high level of uv resistance our prints retain their beautiful colours for many years add colour and style to your living space with this digitally printed painting some are for pleasure and some'

# %%
def preprocess(text):
  text = re.sub(r'[^\w\s\']',' ',text)
  text = re.sub(' +', ' ', text)
  return text.strip().lower()

# %%
preprocess(df['category_description'][0])
# Out:
# '__label__household paper plane design framed wall hanging motivational office decor art prints 8 7 x 8 7 inch set of 4 painting made up in synthetic frame with uv textured print which gives multi effects and attracts towards it this is an special series of paintings which makes your wall very beautiful and gives a royal touch this painting is ready to hang you would be proud to possess this unique painting that is a niche apart we use only the most modern and efficient printing technology on our prints with only the and inks and precision epson roland and hp printers this innovative hd printing technique results in durable and spectacular looking prints of the highest that last a lifetime we print solely with top notch 100 inks to achieve brilliant and true colours due to their high level of uv resistance our prints retain their beautiful colours for many years add colour and style to your living space with this digitally printed painting some are for pleasure and some for eternal b
# ...

# %%
df['category_description'] = df['category_description'].map(preprocess)

# %%
df.head()
# Out:
#              category                                        description  \
# 0  __label__Household  Paper Plane Design Framed Wall Hanging Motivat...
# 1  __label__Household  SAF 'Floral' Framed Painting (Wood, 30 inch x ...
# 2  __label__Household  SAF 'UV Textured Modern Art Print Framed' Pain...
# 3  __label__Household  SAF Flower Print Framed Painting (Synthetic, 1...
# 4  __label__Household  Incredible Gifts India Wooden Happy Birthday U...
#
#                                 category_description
# 0  __label__household paper plane design framed w...
# 1  __label__household saf 'floral' framed paintin...
# 2  __label__household saf 'uv textured modern art...
# 3  __label__household saf flower print framed pai...
# 4  __label__household incredible gifts india wood...

# %%
from sklearn.model_selection import train_test_split
train,test = train_test_split(df,test_size = 0.2)

# %%
train.shape
# Out:
# (40339, 3)

# %%
test.shape
# Out:
# (10085, 3)

# %%
train.head()
# Out:
#                             category  \
# 43754           __label__Electronics
# 6006              __label__Household
# 42819           __label__Electronics
# 36974  __label__Clothing_Accessories
# 2085              __label__Household
#
#                                              description  \
# 43754  OVIO NX40 Rechargeable 3D DLP Active Shutter g...
# 6006   Linenwalas 300 TC Double Bed Stripes Cotton Qu...
# 42819  COSMUS Polyester 29 Ltr Black Laptop Backpack ...
# 36974  Ohuhu Cycling Shorts 3D Padded Bicycle Bike Sh...
# 2085   Italica Furniture 3015 Armchairs (Matte Finish...
#
#                                     category_description
# 43754  __label__electronics ovio nx40 rechargeable 3d...
# 6006   __label__household linenwalas 300 tc double be...
# 42819  __label__electronics cosmus polyester 29 ltr b...
# 36974  __label__clothing_accessories ohuhu cycling sh...
# 2085   __label__household italica furniture 3015 armc...

# %%
test.head()
# Out:
#                    category  \
# 42808  __label__Electronics
# 2196     __label__Household
# 7387     __label__Household
# 41226  __label__Electronics
# 19657        __label__Books
#
#                                              description  \
# 42808  HP Express 27 ltrs Laptop Backpack for Upto 15...
# 2196   La Z Boy Norman Single Seater Recliner (Beige)...
# 7387   EverEx™ Stainless Steel 3-Tier Fruits & Vegeta...
# 41226  SYBA Virtual 7 Surround Sound USB External Ada...
# 19657  Society Tea Regular Tea Pouch, 1kg Truly, tea ...
#
#                                     category_description
# 42808  __label__electronics hp express 27 ltrs laptop...
# 2196   __label__household la z boy norman single seat...
# 7387   __label__household everex stainless steel 3 ti...
# 41226  __label__electronics syba virtual 7 surround s...
# 19657  __label__books society tea regular tea pouch 1...

# %%
# !pip install fasttext
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.8/68.8 kB 2.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached pybind11-2.12.0-py3-none-any.whl (234 kB)
# ...
#   Created wheel for fasttext: filename=fasttext-0.9.2-cp310-cp310-linux_x86_64.whl size=4227137 sha256=9ac1bc6ac21305a75d5e540e891c4e68ee621e542311a34e8dd4f8769f4bad3b
#   Stored in directory: /root/.cache/pip/wheels/a5/13/75/f811c84a8ab36eedbaef977a6a58a98990e8e0f1967f98f394
# Successfully built fasttext
# ...

# %%
train.to_csv("ecommerce.train",columns = ['category_description'],index = False,header = None)
test.to_csv("ecommerce.test",columns = ['category_description'],index = False,header = None)

# %%
import fasttext
model = fasttext.train_supervised(input = "ecommerce.train")

# %%
model.test("ecommerce.test")#size , precision and recall
# Out:
# (10084, 0.9704482348274495, 0.9704482348274495)

# %%
model.predict("pen pencil eraser")
# Out:
# (('__label__books',), array([0.77714723]))

# %%
model.predict("currency")
# Out:
# (('__label__books',), array([0.99996054]))

# %%
model.get_nearest_neighbors("painting")
# Out:
# [(0.9988594651222229, 'kadhai'),
#  (0.9988560676574707, 'paan'),
#  (0.9988560676574707, 'acgc'),
#  (0.9988560676574707, 'pac07'),
#  (0.9988560676574707, 'ginie'),
#  (0.9988551735877991, 'banknotes'),
#  (0.9988551735877991, 'walletdesign'),
#  (0.9988532662391663, 'chillow'),
#  (0.9988499283790588, 'pintuck'),
#  (0.9988499283790588, 'welting')]
